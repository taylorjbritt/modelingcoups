# %%
import pandas as pd
import pickle
import numpy as np

# %%
infile = open('reign_wb_dict','rb')
reign_wb_dict = pickle.load(infile)
infile.close()

# %%
df = pd.read_pickle('../data/year_agg.pkl')

# %%
df.columns
# Out:
# Index(['ccode', 'country', 'leader', 'year', 'month', 'elected', 'age', 'male',
#        'militarycareer', 'tenure_months', 'government', 'anticipation',
#        'ref_ant', 'leg_ant', 'exec_ant', 'irreg_lead_ant', 'election_now',
#        'election_recent', 'leg_recent', 'exec_recent', 'lead_recent',
#        'ref_recent', 'direct_recent', 'indirect_recent', 'victory_recent',
#        'defeat_recent', 'change_recent', 'nochange_recent', 'delayed',
#        'lastelection', 'loss', 'irregular', 'prev_conflict', 'precip',
#        'yearcode', 'coupyear', 'coupsuc'],
#       dtype='object')

# %%
def get_wb_name(val):
    return reign_wb_dict[val]

# %%
df['wb_name'] = df['ccode'].apply(get_wb_name)

# %%
reign_wb_dict[56] = "St. Lucia"

# %%
reign_wb_dict[817] = "Vietnam"

# %%
df.groupby('country').max()
# Out:
#                        ccode                                leader    year  \
# country
# Afghanistan            700.0                                Taraki  2020.0
# Albania                339.0                                  Rama  2020.0
# Algeria                615.0                               Zeroual  2020.0
# Andorra                232.0                                  Reig  2020.0
# Angola                 540.0                                  Neto  2020.0
# Antigua and Barbuda     58.0                             Vere Bird  2020.0
# Argentina              160.0                             de la Rua  2020.0
# Armenia                371.0                         Ter-Petrosyan  2020.0
# Australia              900.0                               Whitlam  2020.0
# Austria                305.0                             Vranitzky  2020.0
# Azerbaijan             373.0                             Mutalibov  2020.0
# ...

# %%
reign_wb_dict_update = reign_wb_dict

# %%
reign_wb_dict_update
# Out:
# {700.0: 'Afghanistan',
#  540.0: 'Angola',
#  339.0: 'Albania',
#  232.0: 'Andorra',
#  696.0: 'United Arab Emirates',
#  160.0: 'Argentina',
#  371.0: 'Armenia',
#  58.0: 'Antigua and Barbuda',
#  900.0: 'Australia',
#  305.0: 'Austria',
#  373.0: 'Azerbaijan',
#  516.0: 'Burundi',
#  211.0: 'Belgium',
#  434.0: 'Benin',
#  439.0: 'Burkina Faso',
#  771.0: 'Bangladesh',
#  355.0: 'Bulgaria',
#  692.0: 'Bahrain',
#  370.0: 'Belarus',
#  80.0: 'Belize',
#  145.0: 'Bolivia',
#  140.0: 'Brazil',
#  53.0: 'Barbados',
#  835.0: 'Brunei',
#  760.0: 'Bhutan',
#  571.0: 'Botswana',
#  20.0: 'Canada',
#  225.0: 'Switzerland',
#  155.0: 'Chile',
#  710.0: 'China',
#  471.0: 'Cameroon',
#  100.0: 'Colombia',
#  581.0: 'Comoros',
#  94.0: 'Costa Rica',
#  40.0: 'Cuba',
#  352.0: 'Cyprus',
#  260.0: 'Germany',
#  522.0: 'Djibouti',
#  54.0: 'Dominica',
#  390.0: 'Denmark',
#  42.0: 'Dominican Republic',
#  615.0: 'Algeria',
#  130.0: 'Ecuador',
#  651.0: 'Egypt',
#  531.0: 'Eritrea',
# ...

# %%
filename = 'reign_wb_dict_update'
outfile = open(filename,'wb')
pickle.dump(reign_wb_dict_update,outfile)
outfile.close()

# %%
inv_dict = {v: k for k, v in reign_wb_dict_update.items()}

# %%
inv_dict
# Out:
# {'Afghanistan': 700.0,
#  'Angola': 540.0,
#  'Albania': 339.0,
#  'Andorra': 232.0,
#  'United Arab Emirates': 696.0,
#  'Argentina': 160.0,
#  'Armenia': 371.0,
#  'Antigua and Barbuda': 58.0,
#  'Australia': 900.0,
#  'Austria': 305.0,
#  'Azerbaijan': 373.0,
#  'Burundi': 516.0,
#  'Belgium': 211.0,
#  'Benin': 434.0,
#  'Burkina Faso': 439.0,
#  'Bangladesh': 771.0,
#  'Bulgaria': 355.0,
#  'Bahrain': 692.0,
#  'Belarus': 370.0,
#  'Belize': 80.0,
#  'Bolivia': 145.0,
#  'Brazil': 140.0,
#  'Barbados': 53.0,
#  'Brunei': 835.0,
#  'Bhutan': 760.0,
#  'Botswana': 571.0,
#  'Canada': 20.0,
#  'Switzerland': 225.0,
#  'Chile': 155.0,
#  'China': 710.0,
#  'Cameroon': 471.0,
#  'Colombia': 100.0,
#  'Comoros': 581.0,
#  'Costa Rica': 94.0,
#  'Cuba': 40.0,
#  'Cyprus': 352.0,
#  'Germany': 260.0,
#  'Djibouti': 522.0,
#  'Dominica': 54.0,
#  'Denmark': 390.0,
#  'Dominican Republic': 42.0,
#  'Algeria': 615.0,
#  'Ecuador': 130.0,
#  'Egypt': 651.0,
#  'Eritrea': 531.0,
# ...

# %%
filename = 'inv_dict'
outfile = open(filename,'wb')
pickle.dump(inv_dict,outfile)
outfile.close()

# %%
wb_gdpg = pd.read_csv('../data/wb_gdp.csv', delimiter='\t')

# %%
yearlist = np.arange(1960, 2020)

# %%
yearliststr = [str(i) for i in yearlist]

# %%
wb_gdpg
# Out:
#      Country Name Country Code         Indicator Name     Indicator Code  \
# 1     Afghanistan          AFG  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 2          Angola          AGO  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 3         Albania          ALB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 4         Andorra          AND  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 5      Arab World          ARB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# ..            ...          ...                    ...                ...
# 259        Kosovo          XKX  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 260   Yemen, Rep.          YEM  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 261  South Africa          ZAF  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 262        Zambia          ZMB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 263      Zimbabwe          ZWE  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
#
#      1960      1961      1962      1963       1964       1965  ...       2010  \
# ...

# %%
dfx = pd.melt(wb_gdpg, id_vars = ['Country Name'], value_vars=yearliststr)

# %%
dfx
# Out:
#        Country Name variable  value
# 0       Afghanistan     1960    NaN
# 1            Angola     1960    NaN
# 2           Albania     1960    NaN
# 3           Andorra     1960    NaN
# 4        Arab World     1960    NaN
# ...             ...      ...    ...
# 15775        Kosovo     2019    NaN
# 15776   Yemen, Rep.     2019    NaN
# 15777  South Africa     2019    NaN
# 15778        Zambia     2019    NaN
# 15779      Zimbabwe     2019    NaN
#
# [15780 rows x 3 columns]

# %%
inv_dict
# Out:
# {'Afghanistan': 700.0,
#  'Angola': 540.0,
#  'Albania': 339.0,
#  'Andorra': 232.0,
#  'United Arab Emirates': 696.0,
#  'Argentina': 160.0,
#  'Armenia': 371.0,
#  'Antigua and Barbuda': 58.0,
#  'Australia': 900.0,
#  'Austria': 305.0,
#  'Azerbaijan': 373.0,
#  'Burundi': 516.0,
#  'Belgium': 211.0,
#  'Benin': 434.0,
#  'Burkina Faso': 439.0,
#  'Bangladesh': 771.0,
#  'Bulgaria': 355.0,
#  'Bahrain': 692.0,
#  'Belarus': 370.0,
#  'Belize': 80.0,
#  'Bolivia': 145.0,
#  'Brazil': 140.0,
#  'Barbados': 53.0,
#  'Brunei': 835.0,
#  'Bhutan': 760.0,
#  'Botswana': 571.0,
#  'Canada': 20.0,
#  'Switzerland': 225.0,
#  'Chile': 155.0,
#  'China': 710.0,
#  'Cameroon': 471.0,
#  'Colombia': 100.0,
#  'Comoros': 581.0,
#  'Costa Rica': 94.0,
#  'Cuba': 40.0,
#  'Cyprus': 352.0,
#  'Germany': 260.0,
#  'Djibouti': 522.0,
#  'Dominica': 54.0,
#  'Denmark': 390.0,
#  'Dominican Republic': 42.0,
#  'Algeria': 615.0,
#  'Ecuador': 130.0,
#  'Egypt': 651.0,
#  'Eritrea': 531.0,
# ...

# %%
def get_cc(val):
    if val in inv_dict:
        return inv_dict[val]
    else:
        return 0

# %%
pd.options.display.max_rows = 999

# %%
dfx['ccode'] = dfx['Country Name'].apply(get_cc)

# %%
inv_dict['Korea, Rep.'] = 732

# %%
inv_dict['Korea, Dem. People’s Rep.'] = 731

# %%
inv_dict['Iran, Islamic Rep.'] = 630

# %%
inv_dict['Russian Federation'] = 365

# %%
inv_dict['Sao Tome and Principe'] = 403

# %%
inv_dict['Egypt, Arab Rep.'] = 651

# %%
inv_dict['Eswatini'] = 572

# %%
inv_dict['Congo, Dem. Rep.'] = 490

# %%
inv_dict['Congo, Rep.'] = 484

# %%
inv_dict['Brunei Darussalam'] = 835

# %%
inv_dict["Cote d'Ivoire"] = 437

# %%
inv_dict["Venezuela, RB"] = 101

# %%
inv_dict["Yemen, Rep."] = 679

# %%
inv_dict["Gambia, The"] = 420.0

# %%
filename = 'inv_dict'
outfile = open(filename,'wb')
pickle.dump(inv_dict,outfile)
outfile.close()

# %%
df.groupby('country').max()
# Out:
#                        ccode                                leader    year  \
# country
# Afghanistan            700.0                                Taraki  2020.0
# Albania                339.0                                  Rama  2020.0
# Algeria                615.0                               Zeroual  2020.0
# Andorra                232.0                                  Reig  2020.0
# Angola                 540.0                                  Neto  2020.0
# Antigua and Barbuda     58.0                             Vere Bird  2020.0
# Argentina              160.0                             de la Rua  2020.0
# Armenia                371.0                         Ter-Petrosyan  2020.0
# Australia              900.0                               Whitlam  2020.0
# Austria                305.0                             Vranitzky  2020.0
# Azerbaijan             373.0                             Mutalibov  2020.0
# ...

# %%
dfx[dfx['variable'] == '1960'].groupby('Country Name').sum().sort_values('ccode')
# Out:
#                                                     value  ccode
# Country Name
# Latin America & the Caribbean (IDA & IBRD count...    0.0    0.0
# St. Martin (French part)                              0.0    0.0
# St. Lucia                                             0.0    0.0
# South Asia (IDA & IBRD)                               0.0    0.0
# East Asia & Pacific (excluding high income)           0.0    0.0
# East Asia & Pacific (IDA & IBRD countries)            0.0    0.0
# East Asia & Pacific                                   0.0    0.0
# Early-demographic dividend                            0.0    0.0
# South Asia                                            0.0    0.0
# Late-demographic dividend                             0.0    0.0
# Latin America & Caribbean                             0.0    0.0
# Latin America & Caribbean (excluding high income)     0.0    0.0
# Curacao                                               0.0    0.0
# ...

# %%
def get_year(val):
    return int(val)

# %%
dfx['year'] = dfx['variable'].apply(get_year)

# %%
dfx['yearcode'] = (dfx['year']) + 10000*dfx['ccode']

# %%
sum(dfx['value'].isna())
# Out:
# 4140

# %%
len(dfx)
# Out:
# 15780

# %%
dfx['gdp_growth'] = dfx['value']

# %%
dfx_limited = dfx[['gdp_growth', 'yearcode']]

# %%
dfx_limited
# Out:
#        gdp_growth   yearcode
# 0             NaN  7001960.0
# 1             NaN  5401960.0
# 2             NaN  3391960.0
# 3             NaN  2321960.0
# 4             NaN     1960.0
# ...           ...        ...
# 15775         NaN  3472019.0
# 15776         NaN  6792019.0
# 15777         NaN  5602019.0
# 15778         NaN  5512019.0
# 15779         NaN  5522019.0
#
# [15780 rows x 2 columns]

# %%
years
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019])

# %%
joint_df = df.join(dfx_limited.set_index('yearcode'), on='yearcode', how = 'inner', rsuffix = '_gdpg')

# %%
joint_df
# Out:
#        ccode country                        leader    year  month  elected  \
# 11       2.0     USA                    Eisenhower  1960.0    1.0      1.0
# 12       2.0     USA                    Eisenhower  1961.0    1.0      1.0
# 13       2.0     USA                       Kennedy  1961.0    1.0      1.0
# 14       2.0     USA                       Kennedy  1962.0    1.0      1.0
# 15       2.0     USA                       Kennedy  1963.0    1.0      1.0
# ...      ...     ...                           ...     ...    ...      ...
# 11363  990.0   Samoa  Tuilaepa Sailele Malielegaoi  2015.0    1.0      1.0
# 11364  990.0   Samoa  Tuilaepa Sailele Malielegaoi  2016.0    1.0      1.0
# 11365  990.0   Samoa  Tuilaepa Sailele Malielegaoi  2017.0    1.0      1.0
# 11366  990.0   Samoa  Tuilaepa Sailele Malielegaoi  2018.0    1.0      1.0
# 11367  990.0   Samoa  Tuilaepa Sailele Malielegaoi  2019.0    1.0      1.0
#
# ...

# %%
joint_df[joint_df['country'] == 'Argentina']
# Out:
#       ccode    country                 leader    year  month  elected   age  \
# 2086  160.0  Argentina               Frondizi  1960.0    1.0      1.0  52.0
# 2087  160.0  Argentina               Frondizi  1961.0    1.0      1.0  53.0
# 2088  160.0  Argentina               Frondizi  1962.0    1.0      1.0  54.0
# 2089  160.0  Argentina                  Guido  1963.0    1.0      0.0  53.0
# 2090  160.0  Argentina           Arturo Illia  1964.0    1.0      1.0  64.0
# 2091  160.0  Argentina           Arturo Illia  1965.0    1.0      1.0  65.0
# 2092  160.0  Argentina           Arturo Illia  1966.0    1.0      1.0  66.0
# 2093  160.0  Argentina                Ongania  1967.0    1.0      0.0  53.0
# 2094  160.0  Argentina                Ongania  1968.0    1.0      0.0  54.0
# 2095  160.0  Argentina                Ongania  1969.0    1.0      0.0  55.0
# 2096  160.0  Argentina                Ongania  1970.0    1.0      0.0  56.0
# ...

# %%
inv_dict
# Out:
# {'Afghanistan': 700.0,
#  'Angola': 540.0,
#  'Albania': 339.0,
#  'Andorra': 232.0,
#  'United Arab Emirates': 696.0,
#  'Argentina': 160.0,
#  'Armenia': 371.0,
#  'Antigua and Barbuda': 58.0,
#  'Australia': 900.0,
#  'Austria': 305.0,
#  'Azerbaijan': 373.0,
#  'Burundi': 516.0,
#  'Belgium': 211.0,
#  'Benin': 434.0,
#  'Burkina Faso': 439.0,
#  'Bangladesh': 771.0,
#  'Bulgaria': 355.0,
#  'Bahrain': 692.0,
#  'Belarus': 370.0,
#  'Belize': 80.0,
#  'Bolivia': 145.0,
#  'Brazil': 140.0,
#  'Barbados': 53.0,
#  'Brunei': 835.0,
#  'Bhutan': 760.0,
#  'Botswana': 571.0,
#  'Canada': 20.0,
#  'Switzerland': 225.0,
#  'Chile': 155.0,
#  'China': 710.0,
#  'Cameroon': 471.0,
#  'Colombia': 100.0,
#  'Comoros': 581.0,
#  'Costa Rica': 94.0,
#  'Cuba': 40.0,
#  'Cyprus': 352.0,
#  'Germany': 260.0,
#  'Djibouti': 522.0,
#  'Dominica': 54.0,
#  'Denmark': 390.0,
#  'Dominican Republic': 42.0,
#  'Algeria': 615.0,
#  'Ecuador': 130.0,
#  'Egypt': 651.0,
#  'Eritrea': 531.0,
# ...

# %%
wdi_total = pd.WDIEXCEL.xlsx
