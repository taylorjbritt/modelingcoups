# %%
import pandas as pd
import pickle
import numpy as np

# %%
infile = open('reign_wb_dict','rb')
reign_wb_dict = pickle.load(infile)
infile.close()

# %%
df = pd.read_pickle('../data/year_agg.pkl')

# %%
df
# Out:
#        ccode country                        leader    year  month  elected  \
# 0        2.0     USA                        Truman  1950.0    1.0      1.0
# 1        2.0     USA                        Truman  1951.0    1.0      1.0
# 2        2.0     USA                        Truman  1952.0    1.0      1.0
# 3        2.0     USA                        Truman  1953.0    1.0      1.0
# 4        2.0     USA                    Eisenhower  1953.0    1.0      1.0
# ...      ...     ...                           ...     ...    ...      ...
# 11364  990.0   Samoa  Tuilaepa Sailele Malielegaoi  2016.0    1.0      1.0
# 11365  990.0   Samoa  Tuilaepa Sailele Malielegaoi  2017.0    1.0      1.0
# 11366  990.0   Samoa  Tuilaepa Sailele Malielegaoi  2018.0    1.0      1.0
# 11367  990.0   Samoa  Tuilaepa Sailele Malielegaoi  2019.0    1.0      1.0
# 11368  990.0   Samoa  Tuilaepa Sailele Malielegaoi  2020.0    1.0      1.0
#
#         age  male  militarycareer  tenure_months  ... nochange_recent  \
# 0      66.0     1             0.0           58.0  ...             0.0
# 1      67.0     1             0.0           70.0  ...             0.0
# 2      68.0     1             0.0           82.0  ...             0.0
# 3      69.0     1             0.0           94.0  ...             0.0
# 4      63.0     1             1.0            1.0  ...             0.0
# ...     ...   ...             ...            ...  ...             ...
# 11364  71.0     1             0.0          206.0  ...             0.0
# 11365  72.0     1             0.0          218.0  ...             0.0
# 11366  73.0     1             0.0          230.0  ...             0.0
# 11367  74.0     1             0.0          242.0  ...             0.0
# 11368  75.0     1             0.0          254.0  ...             0.0
#
#        delayed  lastelection      loss  irregular  prev_conflict    precip  \
# 0          0.0      2.639057  5.327876   7.565793            0.0 -0.069058
# 1          0.0      3.258097  5.384495   7.571989            0.0 -0.202572
# 2          0.0      3.637586  5.438079   7.578145            0.0  0.394373
# 3          0.0      1.098612  1.098612   7.584265            0.0 -0.665329
# 4          0.0      1.098612  1.098612   7.584265            0.0 -0.665329
# ...        ...           ...       ...        ...            ...       ...
# 11364      0.0      4.077538  5.817111   6.476973            0.0 -0.391420
# 11365      0.0      2.397895  5.852202   6.495265            0.0  0.025780
# 11366      0.0      3.135494  5.886104   6.513230            0.0  0.278135
# 11367      0.0      3.555348  5.918894   6.530878            0.0  0.210903
# 11368      0.0      3.850147  5.950643   6.548219            0.0 -0.034972
#
#         yearcode  coupyear  coupsuc
# 0        21950.0     False    False
# 1        21951.0     False    False
# 2        21952.0     False    False
# 3        21953.0     False    False
# 4        21953.0     False    False
# ...          ...       ...      ...
# 11364  9902016.0     False    False
# 11365  9902017.0     False    False
# 11366  9902018.0     False    False
# 11367  9902019.0     False    False
# 11368  9902020.0     False    False
#
# [11369 rows x 37 columns]

# %%
def get_wb_name(val):
    return reign_wb_dict[val]

# %%
df['wb_name'] = df['ccode'].apply(get_wb_name)

# %%
reign_wb_dict[56] = "St. Lucia"

# %%
reign_wb_dict[817] = "Vietnam"

# %%
df
# Out:
#        ccode country                        leader    year  month  elected  \
# 0        2.0     USA                        Truman  1950.0    1.0      1.0
# 1        2.0     USA                        Truman  1951.0    1.0      1.0
# 2        2.0     USA                        Truman  1952.0    1.0      1.0
# 3        2.0     USA                        Truman  1953.0    1.0      1.0
# 4        2.0     USA                    Eisenhower  1953.0    1.0      1.0
# ...      ...     ...                           ...     ...    ...      ...
# 11364  990.0   Samoa  Tuilaepa Sailele Malielegaoi  2016.0    1.0      1.0
# 11365  990.0   Samoa  Tuilaepa Sailele Malielegaoi  2017.0    1.0      1.0
# 11366  990.0   Samoa  Tuilaepa Sailele Malielegaoi  2018.0    1.0      1.0
# 11367  990.0   Samoa  Tuilaepa Sailele Malielegaoi  2019.0    1.0      1.0
# 11368  990.0   Samoa  Tuilaepa Sailele Malielegaoi  2020.0    1.0      1.0
#
#         age  male  militarycareer  tenure_months  ... delayed  lastelection  \
# 0      66.0     1             0.0           58.0  ...     0.0      2.639057
# 1      67.0     1             0.0           70.0  ...     0.0      3.258097
# 2      68.0     1             0.0           82.0  ...     0.0      3.637586
# 3      69.0     1             0.0           94.0  ...     0.0      1.098612
# 4      63.0     1             1.0            1.0  ...     0.0      1.098612
# ...     ...   ...             ...            ...  ...     ...           ...
# 11364  71.0     1             0.0          206.0  ...     0.0      4.077538
# 11365  72.0     1             0.0          218.0  ...     0.0      2.397895
# 11366  73.0     1             0.0          230.0  ...     0.0      3.135494
# 11367  74.0     1             0.0          242.0  ...     0.0      3.555348
# 11368  75.0     1             0.0          254.0  ...     0.0      3.850147
#
#            loss  irregular  prev_conflict    precip   yearcode  coupyear  \
# 0      5.327876   7.565793            0.0 -0.069058    21950.0     False
# 1      5.384495   7.571989            0.0 -0.202572    21951.0     False
# 2      5.438079   7.578145            0.0  0.394373    21952.0     False
# 3      1.098612   7.584265            0.0 -0.665329    21953.0     False
# 4      1.098612   7.584265            0.0 -0.665329    21953.0     False
# ...         ...        ...            ...       ...        ...       ...
# 11364  5.817111   6.476973            0.0 -0.391420  9902016.0     False
# 11365  5.852202   6.495265            0.0  0.025780  9902017.0     False
# 11366  5.886104   6.513230            0.0  0.278135  9902018.0     False
# 11367  5.918894   6.530878            0.0  0.210903  9902019.0     False
# 11368  5.950643   6.548219            0.0 -0.034972  9902020.0     False
#
#        coupsuc         wb_name
# 0        False   United States
# 1        False   United States
# 2        False   United States
# 3        False   United States
# 4        False   United States
# ...        ...             ...
# 11364    False  American Samoa
# 11365    False  American Samoa
# 11366    False  American Samoa
# 11367    False  American Samoa
# 11368    False  American Samoa
#
# [11369 rows x 38 columns]

# %%
reign_wb_dict_update = reign_wb_dict

# %%
filename = 'reign_wb_dict_update'
outfile = open(filename,'wb')
pickle.dump(reign_wb_dict_update,outfile)
outfile.close()

# %%
inv_dict = {v: k for k, v in reign_wb_dict_update.items()}

# %%
inv_dict
# Out:
# {'Afghanistan': 700.0,
#  'Angola': 540.0,
#  'Albania': 339.0,
#  'Andorra': 232.0,
#  'United Arab Emirates': 696.0,
#  'Argentina': 160.0,
#  'Armenia': 371.0,
#  'Antigua and Barbuda': 58.0,
#  'Australia': 900.0,
#  'Austria': 305.0,
#  'Azerbaijan': 373.0,
#  'Burundi': 516.0,
#  'Belgium': 211.0,
#  'Benin': 434.0,
#  'Burkina Faso': 439.0,
#  'Bangladesh': 771.0,
#  'Bulgaria': 355.0,
#  'Bahrain': 692.0,
#  'Belarus': 370.0,
#  'Belize': 80.0,
#  'Bolivia': 145.0,
#  'Brazil': 140.0,
#  'Barbados': 53.0,
#  'Brunei': 835.0,
#  'Bhutan': 760.0,
#  'Botswana': 571.0,
#  'Canada': 20.0,
#  'Switzerland': 225.0,
#  'Chile': 155.0,
#  'China': 710.0,
#  'Cameroon': 471.0,
#  'Colombia': 100.0,
#  'Comoros': 581.0,
#  'Costa Rica': 94.0,
#  'Cuba': 40.0,
#  'Cyprus': 352.0,
#  'Germany': 265,
#  'Djibouti': 522.0,
#  'Dominica': 54.0,
#  'Denmark': 390.0,
#  'Dominican Republic': 42.0,
#  'Algeria': 615.0,
#  'Ecuador': 130.0,
#  'Egypt': 651.0,
#  'Eritrea': 531.0,
#  'Spain': 230.0,
#  'Estonia': 366.0,
#  'Ethiopia': 530.0,
#  'Finland': 375.0,
#  'Fiji': 950.0,
#  'France': 220.0,
#  'Micronesia': 987.0,
#  'Gabon': 481.0,
#  'Georgia': 372.0,
#  'Ghana': 452.0,
#  'Guinea': 438.0,
#  'Equatorial Guinea': 411.0,
#  'Greece': 350.0,
#  'Grenada': 55.0,
#  'Guatemala': 90.0,
#  'Guyana': 110.0,
#  'Honduras': 91.0,
#  'Croatia': 344.0,
#  'Haiti': 41.0,
#  'Hungary': 310.0,
#  'Indonesia': 850.0,
#  'India': 750.0,
#  'Ireland': 205.0,
#  'Iran': 630.0,
#  'Iraq': 645.0,
#  'Iceland': 395.0,
#  'Israel': 666.0,
#  'Italy': 325.0,
#  'Jamaica': 51.0,
#  'Jordan': 663.0,
#  'Japan': 740.0,
#  'Kazakhstan': 705.0,
#  'Kenya': 501.0,
#  'Cambodia': 811.0,
#  'Kiribati': 946.0,
#  'Kuwait': 690.0,
#  'Lebanon': 660.0,
#  'Liberia': 450.0,
#  'Libya': 620.0,
#  'Liechtenstein': 223.0,
#  'Sri Lanka': 780.0,
#  'Lesotho': 570.0,
#  'Lithuania': 368.0,
#  'Luxembourg': 212.0,
#  'Latvia': 367.0,
#  'Morocco': 600.0,
#  'Monaco': 221.0,
#  'Moldova': 359.0,
#  'Madagascar': 580.0,
#  'Maldives': 781.0,
#  'Mexico': 70.0,
#  'Marshall Islands': 983.0,
#  'Mali': 432.0,
#  'Malta': 338.0,
#  'Myanmar': 775.0,
#  'Montenegro': 341.0,
#  'Mongolia': 712.0,
#  'Mozambique': 541.0,
#  'Mauritania': 435.0,
#  'Mauritius': 590.0,
#  'Malawi': 553.0,
#  'Malaysia': 820.0,
#  'Namibia': 565.0,
#  'Niger': 436.0,
#  'Nigeria': 475.0,
#  'Nicaragua': 93.0,
#  'Netherlands': 210.0,
#  'Norway': 385.0,
#  'Nepal': 790.0,
#  'Nauru': 970.0,
#  'New Zealand': 920.0,
#  'Oman': 698.0,
#  'Pakistan': 770.0,
#  'Panama': 95.0,
#  'Peru': 135.0,
#  'Philippines': 840.0,
#  'Palau': 986.0,
#  'Papua New Guinea': 910.0,
#  'Poland': 290.0,
#  'Portugal': 235.0,
#  'Paraguay': 150.0,
#  'Qatar': 694.0,
#  'Romania': 360.0,
#  'Russia': 365.0,
#  'Rwanda': 517.0,
#  'Saudi Arabia': 670.0,
#  'Sudan': 625.0,
#  'Senegal': 433.0,
#  'Singapore': 830.0,
#  'Solomon Islands': 940.0,
#  'Sierra Leone': 451.0,
#  'El Salvador': 92.0,
#  'San Marino': 331.0,
#  'Somalia': 520.0,
#  'Serbia': 345.0,
#  'South Sudan': 626.0,
#  'Suriname': 115.0,
#  'Slovenia': 349.0,
#  'Sweden': 380.0,
#  'Seychelles': 591.0,
#  'Chad': 483.0,
#  'Togo': 461.0,
#  'Thailand': 800.0,
#  'Tajikistan': 702.0,
#  'Turkmenistan': 701.0,
#  'Tonga': 955.0,
#  'Trinidad and Tobago': 52.0,
#  'Tunisia': 616.0,
#  'Turkey': 640.0,
#  'Tuvalu': 947.0,
#  'Tanzania': 510.0,
#  'Uganda': 500.0,
#  'Ukraine': 369.0,
#  'Uruguay': 165.0,
#  'Uzbekistan': 704.0,
#  'Venezuela': 101.0,
#  'Vietnam': 817,
#  'Vanuatu': 935.0,
#  'American Samoa': 990.0,
#  'Kosovo': 347.0,
#  'Yemen': 680,
#  'South Africa': 560.0,
#  'Zambia': 551.0,
#  'Zimbabwe': 552.0,
#  'United States': 2.0,
#  'The Bahamas': 31.0,
#  'Bosnia and Herzegovina': 346.0,
#  'Central African Republic': 482.0,
#  "Côte d'Ivoire": 437.0,
#  'Dem. Rep. Congo': 490.0,
#  'Czech Republic': 315,
#  'Congo': 484.0,
#  'Cabo Verde': 402.0,
#  'United Kingdom': 200.0,
#  'The Gambia': 420.0,
#  'Guinea-Bissau': 404.0,
#  'Kyrgyz Republic': 703.0,
#  'Korea': 732.0,
#  "Dem. People's Rep. Korea": 731.0,
#  'São Tomé and Principe': 403.0,
#  'Slovak Republic': 317.0,
#  'St. Kitts and Nevis': 60.0,
#  'Lao PDR': 812,
#  'Syrian Arab Republic': 652,
#  'St. Vincent and the Grenadines': 57,
#  'Timor-Leste': 860,
#  'St. Lucia': 56,
#  'Macedonia': 343,
#  'Eswatini': 572}

# %%
filename = 'inv_dict'
outfile = open(filename,'wb')
pickle.dump(inv_dict,outfile)
outfile.close()

# %%
wb_gdpg = pd.read_csv('../data/wb_gdp.csv', delimiter='\t')

# %%
years = np.arange(1960, 2020)

# %%
years
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019])

# %%
wb_gdpg.T
# Out:
#                                   0                      1    \
# Country Name                    Aruba            Afghanistan
# Country Code                      ABW                    AFG
# Indicator Name  GDP growth (annual %)  GDP growth (annual %)
# Indicator Code      NY.GDP.MKTP.KD.ZG      NY.GDP.MKTP.KD.ZG
# 1960                              NaN                    NaN
# ...                               ...                    ...
# 2015                        -0.450586                1.45131
# 2016                        -0.211225                2.26031
# 2017                          1.33051                2.66529
# 2018                              NaN                1.03066
# 2019                              NaN                    NaN
#
#                                   2                      3    \
# Country Name                   Angola                Albania
# Country Code                      AGO                    ALB
# Indicator Name  GDP growth (annual %)  GDP growth (annual %)
# Indicator Code      NY.GDP.MKTP.KD.ZG      NY.GDP.MKTP.KD.ZG
# 1960                              NaN                    NaN
# ...                               ...                    ...
# 2015                         0.943576                2.21875
# 2016                          -2.5801                 3.3148
# 2017                        -0.147207                3.82108
# 2018                         -2.13349                4.14524
# 2019                              NaN                    NaN
#
#                                   4                      5    \
# Country Name                  Andorra             Arab World
# Country Code                      AND                    ARB
# Indicator Name  GDP growth (annual %)  GDP growth (annual %)
# Indicator Code      NY.GDP.MKTP.KD.ZG      NY.GDP.MKTP.KD.ZG
# 1960                              NaN                    NaN
# ...                               ...                    ...
# 2015                         0.842204                3.30635
# 2016                          1.88912                3.37262
# 2017                          1.72402               0.832435
# 2018                          1.62935                2.04598
# 2019                              NaN                    NaN
#
#                                   6                      7    \
# Country Name     United Arab Emirates              Argentina
# Country Code                      ARE                    ARG
# Indicator Name  GDP growth (annual %)  GDP growth (annual %)
# Indicator Code      NY.GDP.MKTP.KD.ZG      NY.GDP.MKTP.KD.ZG
# 1960                              NaN                    NaN
# ...                               ...                    ...
# 2015                          5.10594                2.73116
# 2016                          3.06096               -2.08033
# 2017                         0.490861                2.66859
# 2018                          1.72635               -2.48179
# 2019                              NaN                    NaN
#
#                                   8                      9    ...  \
# Country Name                  Armenia         American Samoa  ...
# Country Code                      ARM                    ASM  ...
# Indicator Name  GDP growth (annual %)  GDP growth (annual %)  ...
# Indicator Code      NY.GDP.MKTP.KD.ZG      NY.GDP.MKTP.KD.ZG  ...
# 1960                              NaN                    NaN  ...
# ...                               ...                    ...  ...
# 2015                              3.2                1.40406  ...
# 2016                              0.2               -2.76923  ...
# 2017                              7.5               -5.85443  ...
# 2018                              5.2                2.18487  ...
# 2019                              NaN                    NaN  ...
#
#                                   254                    255  \
# Country Name    Virgin Islands (U.S.)                Vietnam
# Country Code                      VIR                    VNM
# Indicator Name  GDP growth (annual %)  GDP growth (annual %)
# Indicator Code      NY.GDP.MKTP.KD.ZG      NY.GDP.MKTP.KD.ZG
# 1960                              NaN                    NaN
# ...                               ...                    ...
# 2015                         0.194175                6.67929
# 2016                         0.904393                6.21081
# 2017                         -1.69654                6.81225
# 2018                              NaN                7.07579
# 2019                              NaN                    NaN
#
#                                   256                    257  \
# Country Name                  Vanuatu                  World
# Country Code                      VUT                    WLD
# Indicator Name  GDP growth (annual %)  GDP growth (annual %)
# Indicator Code      NY.GDP.MKTP.KD.ZG      NY.GDP.MKTP.KD.ZG
# 1960                              NaN                    NaN
# ...                               ...                    ...
# 2015                              0.2                2.85726
# 2016                              3.5                2.58512
# 2017                              4.4                3.19656
# 2018                              3.2                3.05839
# 2019                              NaN                    NaN
#
#                                   258                    259  \
# Country Name                    Samoa                 Kosovo
# Country Code                      WSM                    XKX
# Indicator Name  GDP growth (annual %)  GDP growth (annual %)
# Indicator Code      NY.GDP.MKTP.KD.ZG      NY.GDP.MKTP.KD.ZG
# 1960                              NaN                    NaN
# ...                               ...                    ...
# 2015                          4.27219                4.09528
# 2016                          8.05416                4.07029
# 2017                          1.01556                4.22609
# 2018                          -2.1681                3.81331
# 2019                              NaN                    NaN
#
#                                   260                    261  \
# Country Name              Yemen, Rep.           South Africa
# Country Code                      YEM                    ZAF
# Indicator Name  GDP growth (annual %)  GDP growth (annual %)
# Indicator Code      NY.GDP.MKTP.KD.ZG      NY.GDP.MKTP.KD.ZG
# 1960                              NaN                    NaN
# ...                               ...                    ...
# 2015                         -16.6785                1.19373
# 2016                         -13.6215               0.399088
# 2017                         -5.94232                1.41451
# 2018                         -2.70147               0.787056
# 2019                              NaN                    NaN
#
#                                   262                    263
# Country Name                   Zambia               Zimbabwe
# Country Code                      ZMB                    ZWE
# Indicator Name  GDP growth (annual %)  GDP growth (annual %)
# Indicator Code      NY.GDP.MKTP.KD.ZG      NY.GDP.MKTP.KD.ZG
# 1960                              NaN                    NaN
# ...                               ...                    ...
# 2015                          2.91988                1.77987
# 2016                          3.75718               0.755869
# 2017                          3.40317                4.70404
# 2018                           3.7949                6.15919
# 2019                              NaN                    NaN
#
# [64 rows x 264 columns]

# %%
wb_gdpg.pivot?

# %%
wb_gdpg.pivot(index='Country Name', columns='Indicator Name')
# Out:
#                             Country Code        Indicator Code  \
# Indicator Name     GDP growth (annual %) GDP growth (annual %)
# Country Name
# Afghanistan                          AFG     NY.GDP.MKTP.KD.ZG
# Albania                              ALB     NY.GDP.MKTP.KD.ZG
# Algeria                              DZA     NY.GDP.MKTP.KD.ZG
# American Samoa                       ASM     NY.GDP.MKTP.KD.ZG
# Andorra                              AND     NY.GDP.MKTP.KD.ZG
# ...                                  ...                   ...
# West Bank and Gaza                   PSE     NY.GDP.MKTP.KD.ZG
# World                                WLD     NY.GDP.MKTP.KD.ZG
# Yemen, Rep.                          YEM     NY.GDP.MKTP.KD.ZG
# Zambia                               ZMB     NY.GDP.MKTP.KD.ZG
# Zimbabwe                             ZWE     NY.GDP.MKTP.KD.ZG
#
#                                     1960                  1961  \
# Indicator Name     GDP growth (annual %) GDP growth (annual %)
# Country Name
# Afghanistan                          NaN                   NaN
# Albania                              NaN                   NaN
# Algeria                              NaN            -13.605441
# American Samoa                       NaN                   NaN
# Andorra                              NaN                   NaN
# ...                                  ...                   ...
# West Bank and Gaza                   NaN                   NaN
# World                                NaN              4.300340
# Yemen, Rep.                          NaN                   NaN
# Zambia                               NaN              1.361382
# Zimbabwe                             NaN              6.316157
#
#                                     1962                  1963  \
# Indicator Name     GDP growth (annual %) GDP growth (annual %)
# Country Name
# Afghanistan                          NaN                   NaN
# Albania                              NaN                   NaN
# Algeria                       -19.685042             34.313729
# American Samoa                       NaN                   NaN
# Andorra                              NaN                   NaN
# ...                                  ...                   ...
# West Bank and Gaza                   NaN                   NaN
# World                           5.553578              5.353422
# Yemen, Rep.                          NaN                   NaN
# Zambia                         -2.490839              3.272393
# Zimbabwe                        1.434471              6.244345
#
#                                     1964                  1965  \
# Indicator Name     GDP growth (annual %) GDP growth (annual %)
# Country Name
# Afghanistan                          NaN                   NaN
# Albania                              NaN                   NaN
# Algeria                         5.839413              6.206898
# American Samoa                       NaN                   NaN
# Andorra                              NaN                   NaN
# ...                                  ...                   ...
# West Bank and Gaza                   NaN                   NaN
# World                           6.714787              5.519477
# Yemen, Rep.                          NaN                   NaN
# Zambia                         12.214048             16.647456
# Zimbabwe                       -1.106172              4.910571
#
#                                     1966                  1967  ...  \
# Indicator Name     GDP growth (annual %) GDP growth (annual %)  ...
# Country Name                                                    ...
# Afghanistan                          NaN                   NaN  ...
# Albania                              NaN                   NaN  ...
# Algeria                        -4.804971              9.452963  ...
# American Samoa                       NaN                   NaN  ...
# Andorra                              NaN                   NaN  ...
# ...                                  ...                   ...  ...
# West Bank and Gaza                   NaN                   NaN  ...
# World                           5.769478              4.486744  ...
# Yemen, Rep.                          NaN                   NaN  ...
# Zambia                         -5.570310              7.919697  ...
# Zimbabwe                        1.523130              8.367009  ...
#
#                                     2010                  2011  \
# Indicator Name     GDP growth (annual %) GDP growth (annual %)
# Country Name
# Afghanistan                    14.362441              0.426355
# Albania                         3.706891              2.545323
# Algeria                         3.600000              2.900000
# American Samoa                  0.442478              0.293686
# Andorra                        -5.358826             -4.646543
# ...                                  ...                   ...
# West Bank and Gaza              8.099089             12.413636
# World                           4.299175              3.132457
# Yemen, Rep.                     7.702307            -12.714897
# Zambia                         10.298206              5.564625
# Zimbabwe                       19.675323             14.193913
#
#                                     2012                  2013  \
# Indicator Name     GDP growth (annual %) GDP growth (annual %)
# Country Name
# Afghanistan                    12.752287              5.600745
# Albania                         1.417524              1.001989
# Algeria                         3.400000              2.800000
# American Samoa                 -4.392387             -2.756508
# Andorra                        -1.615218              0.351645
# ...                                  ...                   ...
# West Bank and Gaza              6.284236              2.217422
# World                           2.507626              2.655492
# Yemen, Rep.                     2.392990              4.823519
# Zambia                          7.597617              5.059376
# Zimbabwe                       16.665429              1.989493
#
#                                     2014                  2015  \
# Indicator Name     GDP growth (annual %) GDP growth (annual %)
# Country Name
# Afghanistan                     2.724543              1.451315
# Albania                         1.774487              2.218751
# Algeria                         3.800000              3.700000
# American Samoa                  0.944882              1.404056
# Andorra                         2.277683              0.842204
# ...                                  ...                   ...
# West Bank and Gaza             -0.181891              3.428732
# World                           2.835050              2.857257
# Yemen, Rep.                    -0.188690            -16.678463
# Zambia                          4.695826              2.919881
# Zimbabwe                        2.376929              1.779873
#
#                                     2016                  2017  \
# Indicator Name     GDP growth (annual %) GDP growth (annual %)
# Country Name
# Afghanistan                     2.260314              2.665292
# Albania                         3.314805              3.821081
# Algeria                         3.200000              1.300000
# American Samoa                 -2.769231             -5.854430
# Andorra                         1.889124              1.724022
# ...                                  ...                   ...
# West Bank and Gaza              4.708435              3.140237
# World                           2.585116              3.196562
# Yemen, Rep.                   -13.621458             -5.942320
# Zambia                          3.757178              3.403169
# Zimbabwe                        0.755869              4.704035
#
#                                     2018                  2019
# Indicator Name     GDP growth (annual %) GDP growth (annual %)
# Country Name
# Afghanistan                     1.030660                   NaN
# Albania                         4.145238                   NaN
# Algeria                         1.400000                   NaN
# American Samoa                  2.184874                   NaN
# Andorra                         1.629345                   NaN
# ...                                  ...                   ...
# West Bank and Gaza              0.905278                   NaN
# World                           3.058395                   NaN
# Yemen, Rep.                    -2.701475                   NaN
# Zambia                          3.794901                   NaN
# Zimbabwe                        6.159190                   NaN
#
# [264 rows x 62 columns]
